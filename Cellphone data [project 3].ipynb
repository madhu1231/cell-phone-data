# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
phone=pd.read_excel('Cellphone.xlsx')

# %%
phone
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0           203   2357    10   135.0         5.20  424         8     1.350
# 1           880   1749    10   125.0         4.00  233         2     1.300
# 2            40   1916    10   110.0         4.70  312         4     1.200
# 3            99   1315    11   118.5         4.00  233         2     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# ..          ...    ...   ...     ...          ...  ...       ...       ...
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem    ram  RearCam  Front_Cam  battery  thickness
# ...

# %%
phone.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
phone.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# ...

# %%
phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %%
phone.value_counts()
# Out:
# Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  internal mem  ram    RearCam  Front_Cam  battery  thickness
# 10          1950   26    118.0   5.0          187  4         1.30      8.0           1.000  8.00     2.0        2000     6.4          1
# 774         1238   20    134.1   4.0          233  2         1.20      8.0           1.000  2.00     0.0        1560     11.7         1
# 880         1749   10    125.0   4.0          233  2         1.30      4.0           1.000  3.15     0.0        1700     9.9          1
#                    11    125.0   4.0          233  2         1.30      4.0           1.000  3.15     0.0        1700     9.9          1
# 907         2087   37    147.0   5.0          294  4         1.30      32.0          3.000  8.00     5.0        2450     7.6          1
#                                                                                                                                      ..
# ...

# %%
phone.nunique()
# Out:
# Product_id       83
# Price            81
# Sale            125
# weight           62
# resoloution      24
# ppi              45
# cpu core          6
# cpu freq         28
# internal mem     10
# ram              12
# RearCam          18
# Front_Cam        15
# battery          55
# thickness        49
# dtype: int64

# %%
phone['cpu core'].unique()
# Out:
# array([8, 2, 4, 6, 1, 0], dtype=int64)

# %%
phone['RearCam'].nunique()
# Out:
# 18

# %%
phone[phone.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Product_id, Price, Sale, weight, resoloution, ppi, cpu core, cpu freq, internal mem, ram, RearCam, Front_Cam, battery, thickness]
# Index: []

# %%
phone.drop_duplicates()
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0           203   2357    10   135.0         5.20  424         8     1.350
# 1           880   1749    10   125.0         4.00  233         2     1.300
# 2            40   1916    10   110.0         4.70  312         4     1.200
# 3            99   1315    11   118.5         4.00  233         2     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# ..          ...    ...   ...     ...          ...  ...       ...       ...
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem    ram  RearCam  Front_Cam  battery  thickness
# ...

# %%
phone.isnull().sum()
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
phone.nlargest(5,'Sale')
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
#
#      internal mem  ram  RearCam  Front_Cam  battery  thickness
# 160          16.0  3.0     21.5       16.0     2700        8.4
# 159         128.0  6.0     20.0        8.0     3400        7.9
# 158          64.0  4.0     20.0       20.0     3000        6.8
# 157         128.0  6.0     20.0        8.0     3400        7.9
# 156         128.0  6.0     12.0       16.0     4080        8.4

# %%
phone.nsmallest(5,'Sale')
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
plt.figure(figsize=(22,5))
phone.boxplot()
# Out:
# <AxesSubplot:>

# %%
phone.boxplot('Sale')
# Out:
# <AxesSubplot:>

# %%
p1=phone[phone['Sale']>8900]

# %%
p1.boxplot('Sale')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
sns.heatmap(phone.corr(),annot=True,cmap='rainbow')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,5))
sns.barplot(x='ram',y='Price',data=phone)
# Out:
# <AxesSubplot:xlabel='ram', ylabel='Price'>

# %%
plt.figure(figsize=(22,5))
sns.barplot(x='cpu core',y='Sale',data=phone)
# Out:
# <AxesSubplot:xlabel='cpu core', ylabel='Sale'>

# %%
plt.figure(figsize=(22,5))
sns.countplot('RearCam',data=phone)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='RearCam', ylabel='count'>

# %%
plt.figure(figsize=(22,7))
sns.set_context('poster',font_scale=(0.6))
sns.barplot(x='internal mem',y='Sale',data=phone,hue='ram')
# Out:
# <AxesSubplot:xlabel='internal mem', ylabel='Sale'>

# %%
plt.figure(figsize=(22,7))
sns.barplot(x='Front_Cam',y='Price',data=phone)
# Out:
# <AxesSubplot:xlabel='Front_Cam', ylabel='Price'>

# %%
plt.figure(figsize=(22,7))
sns.countplot('Front_Cam',data=phone)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Front_Cam', ylabel='count'>

# %%
plt.figure(figsize=(22,7))
sns.barplot(x='thickness',y='Sale',data=phone)
# Out:
# <AxesSubplot:xlabel='thickness', ylabel='Sale'>

# %%
plt.figure(figsize=(22,7))
sns.barplot(x='ram',y='Sale',data=phone)
# Out:
# <AxesSubplot:xlabel='ram', ylabel='Sale'>

# %%
plt.figure(figsize=(22,7))
sns.countplot('ram',data=phone,hue='cpu core')
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ram', ylabel='count'>

# %%
plt.figure(figsize=(22,7))
sns.stripplot(x='ram',y='Price',data=phone)
# Out:
# <AxesSubplot:xlabel='ram', ylabel='Price'>

# %%
plt.figure(figsize=(20,7))
sns.violinplot(x='internal mem',y='Price',data=phone)
# Out:
# <AxesSubplot:xlabel='internal mem', ylabel='Price'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='cpu core',y='weight',data=phone)
# Out:
# <AxesSubplot:xlabel='cpu core', ylabel='weight'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='Front_Cam',y='Sale',data=phone,hue='cpu core')
# Out:
# <AxesSubplot:xlabel='Front_Cam', ylabel='Sale'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='RearCam',y='Sale',data=phone,hue='cpu core')
# Out:
# <AxesSubplot:xlabel='RearCam', ylabel='Sale'>

# %%
plt.figure(figsize=(20,7))
sns.stripplot(x='ram',y='Sale',hue='cpu core',data=phone,jitter=True,split=True)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\categorical.py:2805: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='ram', ylabel='Sale'>

# %%
plt.figure(figsize=(20,7))
sns.factorplot(x='Front_Cam',y='Price',data=phone,kind='bar')
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
plt.figure(figsize=(20,7))
sns.boxplot(x='cpu core',y='Sale',data=phone)
# Out:
# <AxesSubplot:xlabel='cpu core', ylabel='Sale'>

# %%
plt.figure(figsize=(20,7))
sns.violinplot(x='Front_Cam',y='Price',data=phone,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Front_Cam', ylabel='Price'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='RearCam',y='weight',data=phone,palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='RearCam', ylabel='weight'>

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='ram',hue='cpu core',data=phone)
# Out:
# <AxesSubplot:xlabel='ram', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
phone['cpu core'].value_counts().plot.pie(explode=[0.01,0.01,0.01,0.01,0.01,0.01],autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='cpu core'>

# %%
phone1=phone.groupby('cpu core').mean()

# %%
phone1
# Out:
#            Product_id        Price        Sale      weight  resoloution  \
# cpu core
# 0          723.200000   706.800000  869.900000   87.800000     2.120000
# 1         1026.000000   791.000000  110.000000   66.000000     1.500000
# 2          583.000000  1413.428571   65.142857  149.357143     4.571429
# 4          678.320988  2213.382716  603.555556  176.501235     5.434568
# 6          563.000000  2824.000000   65.500000  175.000000     5.500000
# 8          677.865385  2756.557692  792.423077  186.365385     5.757692
#
#                  ppi  cpu freq  internal mem       ram    RearCam  Front_Cam  \
# cpu core
# 0         143.600000  0.000000      0.077600  0.035200   0.660000   0.000000
# 1         121.000000  0.208000      0.000000  0.004000   0.000000   0.000000
# 2         222.428571  1.214286      4.571429  0.790857   3.185714   0.000000
# 4         340.555556  1.648519     27.061728  2.253975  10.398765   3.859259
# ...

# %%
plt.figure(figsize=(20,7))
phone1.plot(kind='bar',y='Sale',color='m',linestyle='dashed',linewidth=3)
# Out:
# <AxesSubplot:xlabel='cpu core'>

# %%
plt.figure(figsize=(20,7))
phone1.plot(kind='pie',y='ram',legend=False,autopct='%2f')
# Out:
# <AxesSubplot:ylabel='ram'>

# %%
phone1.plot(kind='barh',y='Price')
# Out:
# <AxesSubplot:ylabel='cpu core'>

# %%
plt.figure(figsize=(22,7))
sns.barplot(x='cpu freq',y='weight',data=phone)
# Out:
# <AxesSubplot:xlabel='cpu freq', ylabel='weight'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='resoloution',y='Sale',data=phone)
# Out:
# <AxesSubplot:xlabel='resoloution', ylabel='Sale'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='resoloution',y='Price',data=phone)
# Out:
# <AxesSubplot:xlabel='resoloution', ylabel='Price'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='thickness',y='Price',data=phone,hue='cpu core')
# Out:
# <AxesSubplot:xlabel='thickness', ylabel='Price'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='RearCam',y='Price',data=phone)
# Out:
# <AxesSubplot:xlabel='RearCam', ylabel='Price'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='cpu core',y='battery',data=phone)
# Out:
# <AxesSubplot:xlabel='cpu core', ylabel='battery'>

# %%
plt.figure(figsize=(20,7))
sns.factorplot(x='cpu core',y='Price',data=phone)
# Out:
# C:\Users\anil2\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='cpu core',y='Product_id',data=phone)
# Out:
# <AxesSubplot:xlabel='cpu core', ylabel='Product_id'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='ram',y='weight',data=phone)
# Out:
# <AxesSubplot:xlabel='ram', ylabel='weight'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='ram',y='battery',data=phone,hue='cpu core')
# Out:
# <AxesSubplot:xlabel='ram', ylabel='battery'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='ram',y='Product_id',data=phone,hue='cpu core')
# Out:
# <AxesSubplot:xlabel='ram', ylabel='Product_id'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='internal mem',y='Sale',data=phone)
# Out:
# <AxesSubplot:xlabel='internal mem', ylabel='Sale'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='internal mem',y='Price',data=phone)
# Out:
# <AxesSubplot:xlabel='internal mem', ylabel='Price'>

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='internal mem',hue='cpu core',data=phone)
# Out:
# <AxesSubplot:xlabel='internal mem', ylabel='count'>

# %%
phone.nunique()
# Out:
# Product_id       83
# Price            81
# Sale            125
# weight           62
# resoloution      24
# ppi              45
# cpu core          6
# cpu freq         28
# internal mem     10
# ram              12
# RearCam          18
# Front_Cam        15
# battery          55
# thickness        49
# dtype: int64

# %% [markdown]
# # Linear Regression

# %%
y=phone.Price

# %%
y
# Out:
# 0      2357
# 1      1749
# 2      1916
# 3      1315
# 4      1749
#        ...
# 156    3551
# 157    3211
# 158    3260
# 159    3211
# 160    2536
# Name: Price, Length: 161, dtype: int64

# %%
x=phone.iloc[:,3:14]

# %%
x
# Out:
#      weight  resoloution  ppi  cpu core  cpu freq  internal mem    ram  \
# 0     135.0         5.20  424         8     1.350          16.0  3.000
# 1     125.0         4.00  233         2     1.300           4.0  1.000
# 2     110.0         4.70  312         4     1.200           8.0  1.500
# 3     118.5         4.00  233         2     1.300           4.0  0.512
# 4     125.0         4.00  233         2     1.300           4.0  1.000
# ..      ...          ...  ...       ...       ...           ...    ...
# 156   178.0         5.46  538         4     1.875         128.0  6.000
# 157   170.0         5.50  534         4     1.975         128.0  6.000
# 158   150.0         5.50  401         8     2.200          64.0  4.000
# 159   170.0         5.50  534         4     1.975         128.0  6.000
# 160   202.0         6.00  367         8     1.500          16.0  3.000
#
#      RearCam  Front_Cam  battery  thickness
# 0      13.00        8.0     2610        7.4
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model_lnr=LinearRegression()

# %%
model_lnr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict_lnr=model_lnr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(predict_lnr,y_test)
# Out:
# 0.9253583981927102

# %% [markdown]
# # KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model_knr=KNeighborsRegressor()

# %%
model_knr.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
predict_knr=model_knr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(predict_knr,y_test)
# Out:
# 0.8204771304316907

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_dtr= DecisionTreeRegressor()

# %%
model_dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
predict_dtr=model_dtr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(predict_dtr,y_test)
# Out:
# 0.9445083301847608

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_rfr=RandomForestRegressor()

# %%
model_rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
predict_rfr=model_rfr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(predict_rfr,y_test)
# Out:
# 0.9610053394842182
